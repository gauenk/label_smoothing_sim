# %%
# %matplotlib notebook
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using qt instead.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-7a6b33cdc204> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'notebook')
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# <decorator-gen-108> in matplotlib(self, line)
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3417                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3418
# -> 3419         pt.activate_matplotlib(backend)
#    3420         pt.configure_inline_support(self, backend)
#    3421
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     320     from matplotlib import pyplot as plt
#     321
# --> 322     plt.switch_backend(backend)
#     323
#     324     plt.show._needmain = False
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     219         else "matplotlib.backends.backend_{}".format(newbackend.lower()))
#     220
# --> 221     backend_mod = importlib.import_module(backend_name)
#     222     Backend = type(
#     223         "Backend", (matplotlib.backends._Backend,), vars(backend_mod))
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/matplotlib/backends/backend_qt5agg.py in <module>
#       9 from .. import cbook
#      10 from .backend_agg import FigureCanvasAgg
# ---> 11 from .backend_qt5 import (
#      12     QtCore, QtGui, QtWidgets, _BackendQT5, FigureCanvasQT, FigureManagerQT,
#      13     NavigationToolbar2QT, backend_version)
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in <module>
#      13     _Backend, FigureCanvasBase, FigureManagerBase, NavigationToolbar2,
#      14     TimerBase, cursors, ToolContainerBase, StatusbarBase, MouseButton)
# ---> 15 import matplotlib.backends.qt_editor.figureoptions as figureoptions
#      16 from matplotlib.backends.qt_editor.formsubplottool import UiSubplotTool
#      17 from matplotlib.backend_managers import ToolManager
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/matplotlib/backends/qt_editor/figureoptions.py in <module>
#      11 import matplotlib
#      12 from matplotlib import cm, colors as mcolors, markers, image as mimage
# ---> 13 from matplotlib.backends.qt_compat import QtGui
#      14 from matplotlib.backends.qt_editor import _formlayout
#      15
#
# ~/.local/share/virtualenvs/label_smoothing_simulation-V-qZBFIe/lib/python3.6/site-packages/matplotlib/backends/qt_compat.py in <module>
#     156         break
#     157     else:
# --> 158         raise ImportError("Failed to import any qt binding")
#     159 else:  # We should not get there.
#     160     raise AssertionError("Unexpected QT_API: {}".format(QT_API))
#
# ImportError: Failed to import any qt binding

# %% [markdown]
# # Rotating a 3D plot
#
#
# A very simple animation of a rotating 3D plot.
#
# See wire3d_animation_demo for another simple example of animating a 3D plot.

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# load some test data for demonstration and plot a wireframe
X, Y, Z = axes3d.get_test_data(0.1)
ax.plot_wireframe(X, Y, Z, rstride=5, cstride=5)

fig = plt.gcf()
plt.ion()    

# rotate the axes and update
for angle in range(0, 360):
    ax.view_init(30, angle)
    fig.canvas.draw()
    plt.pause(.001)
plt.show()
